# %% [markdown]
# # **Capstone Project: Starbucks Regional Review Intelligence using IBM Granite AI**
#
#
# ## **Background**
# Customer reviews are one of the main sources of organic feedback that can reflect users' real experiences with Starbucks products and services. With reviews coming from various locations and regions, as a data analyst, you must be able to help managers understand patterns of customer satisfaction and complaints based on review data from various regions, in order to optimize service and product quality and increase Starbucks customer retention.
#
# ## **Project Objectives**
# 1. Identify customer sentiment patterns based on regional & cultural context
# 2. Extract complaints and highlight dominant issue patterns for strategic decision-making
# 3. Generate an actionable, impactful regional improvement roadmap that maximizes ROI (Return on Investment).
#
# ## **Raw Dataset**
# - https://www.kaggle.com/datasets/harshalhonde/starbucks-reviews-dataset
#
# ## **Dataset Overview**
# Dataset was cut down to only 3 state with each of maximum 100 reviews to handle the limited resource of the credits given by hactiv8 team, but this project serve on how LLM can handle in data analysis from reviews

# %% [markdown]
# ## **Data Preparation**
#
# - Load and clean review dataset.
# - Extract state from location.
# - Clean review text.
# - Sample balanced data for 3 target states.
#
# This ensure the data is ready for further use

# %%
import pandas as pd
import numpy as np
import re
import nltk
import unicodedata

nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Load dataset
df = pd.read_csv('reviews_data.csv')

# Check few first rows
df.head()

# Drop rows with missing info
initial_shape = df.shape
df.dropna(subset=['Review', 'location'], inplace=True)

# %%
#
def clean_review_text(text):
    """Clean and normalize review text"""
    if not isinstance(text, str):
        return ""

    text = re.sub(r'\b(not|no)\s+(\w+)', r'\1_\2', text, flags=re.IGNORECASE)

    text = re.sub(r'starbucks|sbux|http\S+', '', text, flags=re.IGNORECASE)

    text = re.sub(r'[^\w\s]', '', text)

    return text.strip().lower()

# %%
def extract_state(location_string):
    if isinstance(location_string, str):
        match = re.search(r',\s*([A-Z]{2})$', location_string)
        if match:
            return match.group(1)
    return None

df['state'] = df['location'].apply(extract_state)

# %%
target_states = ['CA', 'FL', 'TX']

df_filtered = df[df['state'].isin(target_states)].copy()

# %%
sampled_df = (
    df_filtered
    .groupby('state')
    .apply(lambda x: x.sample(n=min(len(x), 100), random_state=42))
    .reset_index(drop=True)
)

print("Sampled data shape:", sampled_df.shape)
print(sampled_df['state'].value_counts())
# Out:
# Sampled data shape: (186, 7)
# state
# CA    100
# FL     46
# TX     40
# Name: count, dtype: int64
# /tmp/ipython-input-2604270383.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(n=min(len(x), 100), random_state=42))

# %%
# Clean review
sampled_df['clean_review'] = sampled_df['Review'].apply(clean_review_text)
sampled_df['review_length'] = sampled_df['clean_review'].str.len()
sampled_df['word_count'] = sampled_df['clean_review'].str.split().str.len()

sampled_df.to_csv("cleaned_sampled_reviews.csv", index=False)

# %%
# Dataset shape
print("Dataset shape (rows, columns):", sampled_df.shape)

# Count per state
print("\nReview counts per state:")
print(sampled_df['state'].value_counts())

# Descriptive stats
print("\nReview length & word count stats:")
print(sampled_df[['review_length', 'word_count']].describe())

# sample cleaned reviews
print("\nSample cleaned reviews:")
for i, row in sampled_df[['state', 'clean_review']].sample(5, random_state=1).iterrows():
    print(f"[{row['state']}] {row['clean_review'][:100]}...")
# Out:
# Dataset shape (rows, columns): (186, 10)
#
# Review counts per state:
# state
# CA    100
# FL     46
# TX     40
# Name: count, dtype: int64
#
# Review length & word count stats:
#        review_length  word_count
# count     186.000000  186.000000
# mean      452.698925   86.827957
# std       229.797457   44.479482
# min        14.000000    2.000000
# 25%       271.250000   50.250000
# 50%       450.500000   84.500000
# 75%       636.750000  120.000000
# max       961.000000  189.000000
#
# Sample cleaned reviews:
# [CA] i was poisoned by my smoothie after a few hours my stomachache got worse and worse then came 24 hour...
# [TX] when you get a good barista you get a good drink but those are hard to come by at  now if you ask th...
# [CA] all the money  makes not_only are they ungrateful to their employees but whats the point of being a ...
# [CA] retail locations in hollywood california regularly violate customer rights illegally unethically and...
# [TX] as soon as he sees me walk in the door he has my croissant warming up this group is always nice frie...

# %% [markdown]
# ## **Regional Behavior Enrichment using IBM Granite**
#
# Each state’s customer behavior is extracted using IBM Granite, the variable are:
# - Priority
# - Tolerance
# - Cultural Norm of Feedback
#
# These will add depth to LLM deciding factor of the reviews

# %%
# !pip install langchain_community
# !pip install replicate
# Out:
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.11/dist-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.72)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (3.12.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.4.8)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (0.3.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (2.33.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: replicate in /usr/local/lib/python3.11/dist-packages (1.0.7)
# Requirement already satisfied: httpx<1,>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from replicate) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from replicate) (25.0)
# Requirement already satisfied: pydantic>1.10.7 in /usr/local/lib/python3.11/dist-packages (from replicate) (2.11.7)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from replicate) (4.14.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.21.0->replicate) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.21.0->replicate) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.21.0->replicate) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.21.0->replicate) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.21.0->replicate) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>1.10.7->replicate) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>1.10.7->replicate) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>1.10.7->replicate) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.21.0->replicate) (1.3.1)

# %%
import os
import json
import pandas as pd
from langchain_community.llms import Replicate
from google.colab import userdata

# %%
api_token = userdata.get('api_token')

os.environ["REPLICATE_API_TOKEN"] = api_token

model_id = "ibm-granite/granite-3.3-8b-instruct"
llm = Replicate(
    model=model_id,
    replicate_api_token=api_token
)

# %%
def generate_regional_context_with_ai(state_code):
    prompt = f"""
As a cultural analyst specializing in consumer behavior in the United States, describe the general characteristics of Starbucks customers in the state of {state_code}. Focus on:

- *Primary Priority:* 1–2 short keywords.
- *Tolerance Level:* 1–2 short keywords.
- *Cultural Norm of Feedback:* 1–2 short keywords.

Respond in JSON like:
{{
  "state": "{state_code}",
  "priority": "short_keyword",
  "tolerance": "short_keyword",
  "cultural_norm": "short_keyword"
}}
""".strip()

    try:
        response = llm.invoke(prompt).strip()
        return json.loads(response)
    except Exception as e:
        print(f"Error generating context for {state_code}: {e}")
        return {
            "state": state_code,
            "priority": "general",
            "tolerance": "medium",
            "cultural_norm": "standard"
        }

# %%
unique_states = sampled_df['state'].dropna().unique()

context_list = []

for state in unique_states:
    print(f"Generating context for {state}...")
    context = generate_regional_context_with_ai(state)
    context_list.append(context)
    print(f"{state}: {context}")

# Merge results
regional_context_df = pd.DataFrame(context_list)
sampled_df_with_context = sampled_df.merge(regional_context_df, on='state', how='left')
sampled_df_with_context.to_csv("sampled_df_with_regional_context.csv", index=False)
# Out:
# Generating context for CA...
# CA: {'state': 'CA', 'priority': 'Convenience, Quality', 'tolerance': 'Health-conscious, Eco-friendly', 'cultural_norm': 'Digital-feedback, Social-media-influenced'}
# Generating context for FL...
# FL: {'state': 'FL', 'priority': 'convenience, quality', 'tolerance': 'moderate, adaptable', 'cultural_norm': 'direct, positive'}
# Generating context for TX...
# TX: {'state': 'TX', 'priority': 'convenience, quality', 'tolerance': 'moderate, adaptable', 'cultural_norm': 'direct, feedback-oriented'}

# %%
# Dataset shape
print("Dataset shape (rows, columns):", sampled_df_with_context.shape)

# Count per state
print("\nReview counts per state:")
print(sampled_df_with_context['state'].value_counts())

# Descriptive stats
print("\nReview length & word count stats:")
print(sampled_df_with_context[['review_length', 'word_count']].describe())

# Regional context summary
print("\nRegional context per state:")
print(sampled_df_with_context[['state', 'priority', 'tolerance', 'cultural_norm']].drop_duplicates().to_string(index=False))

# sample cleaned reviews
print("\nSample cleaned reviews:")
for i, row in sampled_df_with_context[['state', 'clean_review']].sample(5, random_state=1).iterrows():
    print(f"[{row['state']}] {row['clean_review'][:100]}...")
# Out:
# Dataset shape (rows, columns): (186, 13)
#
# Review counts per state:
# state
# CA    100
# FL     46
# TX     40
# Name: count, dtype: int64
#
# Review length & word count stats:
#        review_length  word_count
# count     186.000000  186.000000
# mean      452.698925   86.827957
# std       229.797457   44.479482
# min        14.000000    2.000000
# 25%       271.250000   50.250000
# 50%       450.500000   84.500000
# 75%       636.750000  120.000000
# max       961.000000  189.000000
#
# Regional context per state:
# state             priority                      tolerance                             cultural_norm
#    CA Convenience, Quality Health-conscious, Eco-friendly Digital-feedback, Social-media-influenced
#    FL convenience, quality            moderate, adaptable                          direct, positive
#    TX convenience, quality            moderate, adaptable                 direct, feedback-oriented
#
# Sample cleaned reviews:
# [CA] i was poisoned by my smoothie after a few hours my stomachache got worse and worse then came 24 hour...
# [TX] when you get a good barista you get a good drink but those are hard to come by at  now if you ask th...
# [CA] all the money  makes not_only are they ungrateful to their employees but whats the point of being a ...
# [CA] retail locations in hollywood california regularly violate customer rights illegally unethically and...
# [TX] as soon as he sees me walk in the door he has my croissant warming up this group is always nice frie...

# %% [markdown]
# ## **LLM-Based Review Classification**
#
# Using IBM Granite to classify:
# - Sentiment (Positive/Negative/Mixed)
# - Aspect (Service, Product, etc.)
# - Urgency (High/Medium/Low)
#
# with each reviews already given their "summary" by the IBM granite, it's ready for analysis and insight

# %%
import pandas as pd
import time
import re
import textwrap
import replicate


df = sampled_df_with_context

# %%
def analyze_review_batch_lite(reviews, ratings, states, priorities, tolerances, norms, max_reviews=3):
    short_reviews = [textwrap.shorten(str(r), width=100, placeholder="...") for r in reviews[:max_reviews]]
    ratings = ratings[:max_reviews]
    states = states[:max_reviews]
    priorities = priorities[:max_reviews]
    tolerances = tolerances[:max_reviews]
    norms = norms[:max_reviews]

    review_batch = "\n".join([
        f"[{i}] \"{r}\" | Rating: {rat} | State: {st} | Priority: {prio} | Tolerance: {tol} | Norm: {norm}"
        for i, (r, rat, st, prio, tol, norm) in enumerate(zip(short_reviews, ratings, states, priorities, tolerances, norms))
    ])

    prompt = f"""
You are an AI model that classifies customer reviews based on sentiment, aspect, and urgency.

Respond in this exact format (strictly use pick one!):
[<index>] | Sentiment: <Positive/Negative/Mixed> | Aspect: <Service/Product/Ambiance/Wait Time/Price/Cleanliness/Availability/Unknown> | Urgency: <Low/Medium/High>

Here are the reviews:
{review_batch}
"""

    return safe_replicate_run(prompt)

# %%
VALID_ASPECTS = {
    'service': 'Service',
    'product': 'Product',
    'ambiance': 'Ambiance',
    'wait time': 'Wait Time',
    'price': 'Price',
    'cleanliness': 'Cleanliness',
    'availability': 'Availability',
    'unknown': 'Unknown'
}

def normalize_aspect(raw_aspect):
    aspect_cleaned = raw_aspect.strip().lower()

    # Direct match first
    if aspect_cleaned in VALID_ASPECTS:
        return VALID_ASPECTS[aspect_cleaned]

    # Fuzzy/partial matching
    for key in VALID_ASPECTS:
        if key in aspect_cleaned:
            return VALID_ASPECTS[key]

    return 'Unknown'  # Fallback

def parse_batch_output(output_text):
    results = []
    lines = output_text.strip().split("\n")

    for line in lines:
        print("Parsing line:", line)

        match_colon = re.match(
    r"\[<?(\d+)>?\]\s*\|\s*Sentiment:?\s*(\w+)\s*\|\s*Aspect:?\s*([A-Za-z\s\/\-]+)\s*\|\s*Urgency:?\s*(\w+)",
    line, re.IGNORECASE
)
        if match_colon:
            try:
                idx = int(match_colon.group(1))
                sentiment = match_colon.group(2).capitalize()
                raw_aspect = match_colon.group(3)
                aspect = normalize_aspect(raw_aspect)
                urgency = match_colon.group(4).capitalize()

                results.append({
                    'batch_index': idx,
                    'sentiment': sentiment,
                    'aspect': aspect,
                    'urgency': urgency
                })
                continue
            except Exception as e:
                print(f"Error parsing colon format: {e}")

        match_simple = re.match(
    r"\[<?(\d+)>?\]\s*\|\s*(\w+)\s*\|\s*([A-Za-z\s\/\-]+)\s*\|\s*(\w+)",
    line, re.IGNORECASE
)
        if match_simple:
            try:
                idx = int(match_simple.group(1))
                sentiment = match_simple.group(2).capitalize()
                raw_aspect = match_simple.group(3)
                aspect = normalize_aspect(raw_aspect)
                urgency = match_simple.group(4).capitalize()

                results.append({
                    'batch_index': idx,
                    'sentiment': sentiment,
                    'aspect': aspect,
                    'urgency': urgency
                })
            except Exception as e:
                print(f"Error parsing fallback format: {e}")
        else:
            print("Unrecognized format:", line)

    return results

# %%
def parse_batch_output_with_retry(output_text, expected_count, max_retries=3):
    for attempt in range(1, max_retries + 1):
        parsed_outputs = parse_batch_output(output_text)

        if len(parsed_outputs) == expected_count:
            print(f"Parsed {len(parsed_outputs)}/{expected_count} successfully")
            return parsed_outputs

        print(f"Retry {attempt}: Parsed {len(parsed_outputs)}/{expected_count}")
        time.sleep(1)

    print(f"Failed to parse after {max_retries} attempts")
    return []

# %%
def safe_replicate_run(prompt, retries=2):
    for attempt in range(retries):
        try:
            output = replicate.run(
                "ibm-granite/granite-3.3-8b-instruct",
                input={
                    "prompt": prompt,
                    "temperature": 0.1,
                    "max_new_tokens": 120,
                    "top_p": 0.95
                }
            )
            return "".join(output).strip()
        except Exception as e:
            print(f"Attempt {attempt+1} failed: {e}")
            time.sleep(3)
    return ""

# %%
batch_size = 3
results = []

for i in range(0, len(df), batch_size):
    batch = df.iloc[i:i + batch_size]

    print(f"\nProcessing batch {i}-{i + len(batch)}")

    output = analyze_review_batch_lite(
        reviews=batch['clean_review'].tolist(),
        ratings=batch['Rating'].tolist(),
        states=batch['state'].tolist(),
        priorities=batch['priority'].tolist(),
        tolerances=batch['tolerance'].tolist(),
        norms=batch['cultural_norm'].tolist(),
        max_reviews=batch_size
    )

    parsed_outputs = parse_batch_output_with_retry(output, expected_count=len(batch), max_retries=3)

    if parsed_outputs:
        for parsed in parsed_outputs:
            original_idx = batch.iloc[parsed['batch_index']].name
            results.append({
                'original_index': original_idx,
                **parsed
            })
    else:
        print(f"Skipping batch {i}-{i + len(batch)} due to repeated parsing errors.")

    print(f"Processed {min(i + batch_size, len(df))}/{len(df)}")
    time.sleep(2)
# Out:
# Processing batch 0-3
# Parsing line: [0] | Sentiment: Mixed | Aspect: Price | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Price | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsed 3/3 successfully
# Processed 3/186
#
# Processing batch 3-6
# Parsing line: [0] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Price | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Availability | Urgency: Low
# Parsed 3/3 successfully
# Processed 6/186
#
# Processing batch 6-9
# Parsing line: [0] | Sentiment: Negative | Aspect: Ambiance | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Convenience | Urgency: Low
# Parsed 3/3 successfully
# Processed 9/186
#
# Processing batch 9-12
# Parsing line: [0] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Convenience | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Parsed 3/3 successfully
# Processed 12/186
#
# Processing batch 12-15
# Parsing line: [0] | Sentiment: Negative | Aspect: Service | Urgency: High
# Parsing line: [1] | Sentiment: Mixed | Aspect: Convenience | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Parsed 3/3 successfully
# Processed 15/186
#
# Processing batch 15-18
# Parsing line: [0] | Sentiment: Mixed | Aspect: Price | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality, Cleanliness | Urgency: Medium
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Quality, Cleanliness | Urgency: Medium
# Retry 1: Parsed 2/3
# Parsing line: [0] | Sentiment: Mixed | Aspect: Price | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality, Cleanliness | Urgency: Medium
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Quality, Cleanliness | Urgency: Medium
# Retry 2: Parsed 2/3
# Parsing line: [0] | Sentiment: Mixed | Aspect: Price | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality, Cleanliness | Urgency: Medium
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Quality, Cleanliness | Urgency: Medium
# Retry 3: Parsed 2/3
# Failed to parse after 3 attempts
# Skipping batch 15-18 due to repeated parsing errors.
# Processed 18/186
#
# Processing batch 18-21
# Parsing line: [0] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsing line: [1] | Sentiment: Neutral | Aspect: Service | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Price | Urgency: High
# Parsed 3/3 successfully
# Processed 21/186
#
# Processing batch 21-24
# Parsing line: [0] | Sentiment: Mixed | Aspect: Service | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality (implied from "representation") | Urgency: Medium
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Quality (implied from "representation") | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Convenience (implied from "not_refundable" and refund policy) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Convenience (implied from "not_refundable" and refund policy) | Urgency: Low
# Retry 1: Parsed 1/3
# Parsing line: [0] | Sentiment: Mixed | Aspect: Service | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality (implied from "representation") | Urgency: Medium
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Quality (implied from "representation") | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Convenience (implied from "not_refundable" and refund policy) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Convenience (implied from "not_refundable" and refund policy) | Urgency: Low
# Retry 2: Parsed 1/3
# Parsing line: [0] | Sentiment: Mixed | Aspect: Service | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality (implied from "representation") | Urgency: Medium
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Quality (implied from "representation") | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Convenience (implied from "not_refundable" and refund policy) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Convenience (implied from "not_refundable" and refund policy) | Urgency: Low
# Retry 3: Parsed 1/3
# Failed to parse after 3 attempts
# Skipping batch 21-24 due to repeated parsing errors.
# Processed 24/186
#
# Processing batch 24-27
# Parsing line: [0] | Sentiment: Positive | Aspect: Ambiance, Service | Urgency: Low
# Unrecognized format: [0] | Sentiment: Positive | Aspect: Ambiance, Service | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Wait Time | Urgency: High
# Parsing line: [2] | Sentiment: Unknown (no explicit sentiment expressed) | Aspect: Order Accuracy | Urgency: Low
# Unrecognized format: [2] | Sentiment: Unknown (no explicit sentiment expressed) | Aspect: Order Accuracy | Urgency: Low
# Retry 1: Parsed 1/3
# Parsing line: [0] | Sentiment: Positive | Aspect: Ambiance, Service | Urgency: Low
# Unrecognized format: [0] | Sentiment: Positive | Aspect: Ambiance, Service | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Wait Time | Urgency: High
# Parsing line: [2] | Sentiment: Unknown (no explicit sentiment expressed) | Aspect: Order Accuracy | Urgency: Low
# Unrecognized format: [2] | Sentiment: Unknown (no explicit sentiment expressed) | Aspect: Order Accuracy | Urgency: Low
# Retry 2: Parsed 1/3
# Parsing line: [0] | Sentiment: Positive | Aspect: Ambiance, Service | Urgency: Low
# Unrecognized format: [0] | Sentiment: Positive | Aspect: Ambiance, Service | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Wait Time | Urgency: High
# Parsing line: [2] | Sentiment: Unknown (no explicit sentiment expressed) | Aspect: Order Accuracy | Urgency: Low
# Unrecognized format: [2] | Sentiment: Unknown (no explicit sentiment expressed) | Aspect: Order Accuracy | Urgency: Low
# Retry 3: Parsed 1/3
# Failed to parse after 3 attempts
# Skipping batch 24-27 due to repeated parsing errors.
# Processed 27/186
#
# Processing batch 27-30
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Product | Urgency: High
# Parsed 3/3 successfully
# Processed 30/186
#
# Processing batch 30-33
# Parsing line: [0] | Sentiment: Positive | Aspect: Service, Product | Urgency: Low
# Unrecognized format: [0] | Sentiment: Positive | Aspect: Service, Product | Urgency: Low
# Parsing line: [1] | Sentiment: Positive | Aspect: Service, Food, Drinks | Urgency: Low
# Unrecognized format: [1] | Sentiment: Positive | Aspect: Service, Food, Drinks | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Product | Urgency: Low
# Retry 1: Parsed 1/3
# Parsing line: [0] | Sentiment: Positive | Aspect: Service, Product | Urgency: Low
# Unrecognized format: [0] | Sentiment: Positive | Aspect: Service, Product | Urgency: Low
# Parsing line: [1] | Sentiment: Positive | Aspect: Service, Food, Drinks | Urgency: Low
# Unrecognized format: [1] | Sentiment: Positive | Aspect: Service, Food, Drinks | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Product | Urgency: Low
# Retry 2: Parsed 1/3
# Parsing line: [0] | Sentiment: Positive | Aspect: Service, Product | Urgency: Low
# Unrecognized format: [0] | Sentiment: Positive | Aspect: Service, Product | Urgency: Low
# Parsing line: [1] | Sentiment: Positive | Aspect: Service, Food, Drinks | Urgency: Low
# Unrecognized format: [1] | Sentiment: Positive | Aspect: Service, Food, Drinks | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Product | Urgency: Low
# Retry 3: Parsed 1/3
# Failed to parse after 3 attempts
# Skipping batch 30-33 due to repeated parsing errors.
# Processed 33/186
#
# Processing batch 33-36
# Parsing line: [0] | Sentiment: Negative | Aspect: Price | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Service, Safety | Urgency: High
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Service, Safety | Urgency: High
# Parsing line: [2] | Sentiment: Mixed | Aspect: Order Accuracy | Urgency: Medium
# Retry 1: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Price | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Service, Safety | Urgency: High
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Service, Safety | Urgency: High
# Parsing line: [2] | Sentiment: Mixed | Aspect: Order Accuracy | Urgency: Medium
# Retry 2: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Price | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Service, Safety | Urgency: High
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Service, Safety | Urgency: High
# Parsing line: [2] | Sentiment: Mixed | Aspect: Order Accuracy | Urgency: Medium
# Retry 3: Parsed 2/3
# Failed to parse after 3 attempts
# Skipping batch 33-36 due to repeated parsing errors.
# Processed 36/186
#
# Processing batch 36-39
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Parsing line: [2] | Sentiment: Mixed | Aspect: Food | Urgency: Low
# Parsed 3/3 successfully
# Processed 39/186
#
# Processing batch 39-42
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Retry 1: Parsed 1/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Retry 2: Parsed 1/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Retry 3: Parsed 1/3
# Failed to parse after 3 attempts
# Skipping batch 39-42 due to repeated parsing errors.
# Processed 42/186
#
# Processing batch 42-45
# Parsing line: [0] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [2] | Sentiment: Unknown | Aspect: Quality | Urgency: Low (Note: The review does not explicitly express sentiment, but it describes an incident that could be interpreted negatively, hence 'Unknown' sentiment. The aspect is identified as 'Quality' due to the mention of another customer's latte.) | Urgency: Low
# Parsed 3/3 successfully
# Processed 45/186
#
# Processing batch 45-48
# Parsing line: [0] | Sentiment: Mixed | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Unrecognized format: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality | Urgency: Low
# Retry 1: Parsed 2/3
# Parsing line: [0] | Sentiment: Mixed | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Unrecognized format: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality | Urgency: Low
# Retry 2: Parsed 2/3
# Parsing line: [0] | Sentiment: Mixed | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Unrecognized format: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality | Urgency: Low
# Retry 3: Parsed 2/3
# Failed to parse after 3 attempts
# Skipping batch 45-48 due to repeated parsing errors.
# Processed 48/186
#
# Processing batch 48-51
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Product | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Service | Urgency: High
# Parsed 3/3 successfully
# Processed 51/186
#
# Processing batch 51-54
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Food (Coffee Drinks, Muffins, Yogurt) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Food (Coffee Drinks, Muffins, Yogurt) | Urgency: Low
# Retry 1: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Food (Coffee Drinks, Muffins, Yogurt) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Food (Coffee Drinks, Muffins, Yogurt) | Urgency: Low
# Retry 2: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Food (Coffee Drinks, Muffins, Yogurt) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Food (Coffee Drinks, Muffins, Yogurt) | Urgency: Low
# Retry 3: Parsed 2/3
# Failed to parse after 3 attempts
# Skipping batch 51-54 due to repeated parsing errors.
# Processed 54/186
#
# Processing batch 54-57
# Parsing line: [0] | Sentiment: Positive | Aspect: Quality | Urgency: Low
# Parsing line: [1] | Sentiment: Positive | Aspect: Convenience | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsed 3/3 successfully
# Processed 57/186
#
# Processing batch 57-60
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Order Processing | Urgency: High
# Parsed 3/3 successfully
# Processed 60/186
#
# Processing batch 60-63
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsed 3/3 successfully
# Processed 63/186
#
# Processing batch 63-66
# Parsing line: [0] | Sentiment: Positive | Aspect: Quality | Urgency: Low
# Parsing line: [1] | Sentiment: Positive | Aspect: Convenience, Quality | Urgency: Low
# Unrecognized format: [1] | Sentiment: Positive | Aspect: Convenience, Quality | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Retry 1: Parsed 2/3
# Parsing line: [0] | Sentiment: Positive | Aspect: Quality | Urgency: Low
# Parsing line: [1] | Sentiment: Positive | Aspect: Convenience, Quality | Urgency: Low
# Unrecognized format: [1] | Sentiment: Positive | Aspect: Convenience, Quality | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Retry 2: Parsed 2/3
# Parsing line: [0] | Sentiment: Positive | Aspect: Quality | Urgency: Low
# Parsing line: [1] | Sentiment: Positive | Aspect: Convenience, Quality | Urgency: Low
# Unrecognized format: [1] | Sentiment: Positive | Aspect: Convenience, Quality | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Retry 3: Parsed 2/3
# Failed to parse after 3 attempts
# Skipping batch 63-66 due to repeated parsing errors.
# Processed 66/186
#
# Processing batch 66-69
# Parsing line: [0] | Sentiment: Negative | Aspect: Service | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Service | Urgency: High
# Parsed 3/3 successfully
# Processed 69/186
#
# Processing batch 69-72
# Parsing line: [0] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsing line: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Unrecognized format: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality (inferred from context) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Quality (inferred from context) | Urgency: Low
# Retry 1: Parsed 1/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsing line: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Unrecognized format: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality (inferred from context) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Quality (inferred from context) | Urgency: Low
# Retry 2: Parsed 1/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsing line: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Unrecognized format: [1] | Sentiment: N/A | Aspect: N/A | Urgency: N/A
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality (inferred from context) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Negative | Aspect: Quality (inferred from context) | Urgency: Low
# Retry 3: Parsed 1/3
# Failed to parse after 3 attempts
# Skipping batch 69-72 due to repeated parsing errors.
# Processed 72/186
#
# Processing batch 72-75
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Rewards Program | Urgency: High
# Retry 1: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Rewards Program | Urgency: High
# Retry 2: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Quality, Convenience | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Rewards Program | Urgency: High
# Retry 3: Parsed 2/3
# Failed to parse after 3 attempts
# Skipping batch 72-75 due to repeated parsing errors.
# Processed 75/186
#
# Processing batch 75-78
# Parsing line: [0] | Sentiment: Mixed | Aspect: Quality | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsed 3/3 successfully
# Processed 78/186
#
# Processing batch 78-81
# Parsing line: [0] | Sentiment: Mixed | Aspect: Price | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Availability | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsed 3/3 successfully
# Processed 81/186
#
# Processing batch 81-84
# Parsing line: [0] | Sentiment: Negative | Aspect: Temperature | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Product (Green Matcha Drink) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Product (Green Matcha Drink) | Urgency: Low
# Retry 1: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Temperature | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Product (Green Matcha Drink) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Product (Green Matcha Drink) | Urgency: Low
# Retry 2: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Temperature | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Product (Green Matcha Drink) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Product (Green Matcha Drink) | Urgency: Low
# Retry 3: Parsed 2/3
# Failed to parse after 3 attempts
# Skipping batch 81-84 due to repeated parsing errors.
# Processed 84/186
#
# Processing batch 84-87
# Parsing line: [0] | Sentiment: Negative | Aspect: Service | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Order Accuracy | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Store Experience | Urgency: Low
# Parsed 3/3 successfully
# Processed 87/186
#
# Processing batch 87-90
# Parsing line: [0] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Price | Urgency: High
# Parsed 3/3 successfully
# Processed 90/186
#
# Processing batch 90-93
# Parsing line: [0] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsing line: [1] | Sentiment: Mixed | Aspect: Product | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsed 3/3 successfully
# Processed 93/186
#
# Processing batch 93-96
# Parsing line: [0] | Sentiment: Mixed | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Mixed | Aspect: Quality | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsed 3/3 successfully
# Processed 96/186
#
# Processing batch 96-99
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [0] | Sentiment: Mixed | Aspect: Convenience | Urgency: Low
# Parsing line: [1] | Sentiment: Positive | Aspect: Quality | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsed 3/3 successfully
# Processed 99/186
#
# Processing batch 99-102
# Parsing line: [0] | Sentiment: Mixed | Aspect: Quality | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Parsed 3/3 successfully
# Processed 102/186
#
# Processing batch 102-105
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Marketing Practices (implied from 'ads via email') | Urgency: Low
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Marketing Practices (implied from 'ads via email') | Urgency: Low
# Retry 1: Parsed 0/3
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Marketing Practices (implied from 'ads via email') | Urgency: Low
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Marketing Practices (implied from 'ads via email') | Urgency: Low
# Retry 2: Parsed 0/3
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: Medium
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Marketing Practices (implied from 'ads via email') | Urgency: Low
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Marketing Practices (implied from 'ads via email') | Urgency: Low
# Retry 3: Parsed 0/3
# Failed to parse after 3 attempts
# Skipping batch 102-105 due to repeated parsing errors.
# Processed 105/186
#
# Processing batch 105-108
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Parsed 3/3 successfully
# Processed 108/186
#
# Processing batch 108-111
# Parsing line: [<index>0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Unrecognized format: [<index>0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [<index>1] | Sentiment: Negative | Aspect: Quality | Urgency: Low
# Unrecognized format: [<index>1] | Sentiment: Negative | Aspect: Quality | Urgency: Low
# Parsing line: [<index>2] | Sentiment: No Review | Aspect: N/A | Urgency: N/A
# Unrecognized format: [<index>2] | Sentiment: No Review | Aspect: N/A | Urgency: N/A
# Retry 1: Parsed 0/3
# Parsing line: [<index>0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Unrecognized format: [<index>0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [<index>1] | Sentiment: Negative | Aspect: Quality | Urgency: Low
# Unrecognized format: [<index>1] | Sentiment: Negative | Aspect: Quality | Urgency: Low
# Parsing line: [<index>2] | Sentiment: No Review | Aspect: N/A | Urgency: N/A
# Unrecognized format: [<index>2] | Sentiment: No Review | Aspect: N/A | Urgency: N/A
# Retry 2: Parsed 0/3
# Parsing line: [<index>0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Unrecognized format: [<index>0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [<index>1] | Sentiment: Negative | Aspect: Quality | Urgency: Low
# Unrecognized format: [<index>1] | Sentiment: Negative | Aspect: Quality | Urgency: Low
# Parsing line: [<index>2] | Sentiment: No Review | Aspect: N/A | Urgency: N/A
# Unrecognized format: [<index>2] | Sentiment: No Review | Aspect: N/A | Urgency: N/A
# Retry 3: Parsed 0/3
# Failed to parse after 3 attempts
# Skipping batch 108-111 due to repeated parsing errors.
# Processed 111/186
#
# Processing batch 111-114
# Parsing line: [<0>] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsing line: [<1>] | Sentiment: Negative | Aspect: Wait Time | Urgency: High
# Parsing line: [<2>] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsed 3/3 successfully
# Processed 114/186
#
# Processing batch 114-117
# Parsing line: [0] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Product | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsed 3/3 successfully
# Processed 117/186
#
# Processing batch 117-120
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Product | Urgency: High
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Product | Urgency: High
# Parsing line: [0] "i am suffering from a health condition where i cannot have cheese in my sandwich as has no..."
# Unrecognized format: [0] "i am suffering from a health condition where i cannot have cheese in my sandwich as has no..."
# Parsing line:
# Unrecognized format:
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Parsing line: [1] "i have been a loyal sb gold card member for more than 10 years each day i buy 2 beverages and on..."
# Unrecognized format: [1] "i have been a loyal sb gold card member for more than 10 years each day i buy 2 beverages and on..."
# Parsing line:
# Unrecognized format:
# Parsing line: [<index>] | Sentiment: Positive | Aspect: Location | Urgency: Low
# Unrecognized format: [<index>] | Sentiment: Positive | Aspect: Location | Urgency: Low
# Parsing line: [2] "19127 biscayne blvd aventura florida this place is located in the one of the beautiful locations..."
# Unrecognized format: [2] "19127 biscayne blvd aventura florida this place is located in the one of the beautiful locations..."
# Retry 1: Parsed 0/3
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Product | Urgency: High
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Product | Urgency: High
# Parsing line: [0] "i am suffering from a health condition where i cannot have cheese in my sandwich as has no..."
# Unrecognized format: [0] "i am suffering from a health condition where i cannot have cheese in my sandwich as has no..."
# Parsing line:
# Unrecognized format:
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Parsing line: [1] "i have been a loyal sb gold card member for more than 10 years each day i buy 2 beverages and on..."
# Unrecognized format: [1] "i have been a loyal sb gold card member for more than 10 years each day i buy 2 beverages and on..."
# Parsing line:
# Unrecognized format:
# Parsing line: [<index>] | Sentiment: Positive | Aspect: Location | Urgency: Low
# Unrecognized format: [<index>] | Sentiment: Positive | Aspect: Location | Urgency: Low
# Parsing line: [2] "19127 biscayne blvd aventura florida this place is located in the one of the beautiful locations..."
# Unrecognized format: [2] "19127 biscayne blvd aventura florida this place is located in the one of the beautiful locations..."
# Retry 2: Parsed 0/3
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Product | Urgency: High
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Product | Urgency: High
# Parsing line: [0] "i am suffering from a health condition where i cannot have cheese in my sandwich as has no..."
# Unrecognized format: [0] "i am suffering from a health condition where i cannot have cheese in my sandwich as has no..."
# Parsing line:
# Unrecognized format:
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Parsing line: [1] "i have been a loyal sb gold card member for more than 10 years each day i buy 2 beverages and on..."
# Unrecognized format: [1] "i have been a loyal sb gold card member for more than 10 years each day i buy 2 beverages and on..."
# Parsing line:
# Unrecognized format:
# Parsing line: [<index>] | Sentiment: Positive | Aspect: Location | Urgency: Low
# Unrecognized format: [<index>] | Sentiment: Positive | Aspect: Location | Urgency: Low
# Parsing line: [2] "19127 biscayne blvd aventura florida this place is located in the one of the beautiful locations..."
# Unrecognized format: [2] "19127 biscayne blvd aventura florida this place is located in the one of the beautiful locations..."
# Retry 3: Parsed 0/3
# Failed to parse after 3 attempts
# Skipping batch 117-120 due to repeated parsing errors.
# Processed 120/186
#
# Processing batch 120-123
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [<index>] | Sentiment: Mixed | Aspect: Service | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Mixed | Aspect: Service | Urgency: Medium
# Parsing line: [<index>] | Sentiment: Mixed | Aspect: Convenience | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Mixed | Aspect: Convenience | Urgency: Medium
# Retry 1: Parsed 0/3
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [<index>] | Sentiment: Mixed | Aspect: Service | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Mixed | Aspect: Service | Urgency: Medium
# Parsing line: [<index>] | Sentiment: Mixed | Aspect: Convenience | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Mixed | Aspect: Convenience | Urgency: Medium
# Retry 2: Parsed 0/3
# Parsing line: [<index>] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Unrecognized format: [<index>] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [<index>] | Sentiment: Mixed | Aspect: Service | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Mixed | Aspect: Service | Urgency: Medium
# Parsing line: [<index>] | Sentiment: Mixed | Aspect: Convenience | Urgency: Medium
# Unrecognized format: [<index>] | Sentiment: Mixed | Aspect: Convenience | Urgency: Medium
# Retry 3: Parsed 0/3
# Failed to parse after 3 attempts
# Skipping batch 120-123 due to repeated parsing errors.
# Processed 123/186
#
# Processing batch 123-126
# Parsing line: [<0>] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsing line: [<1>] | Sentiment: Negative | Aspect: Promotion/Email | Urgency: Medium
# Parsing line: [<2>] | Sentiment: Negative | Aspect: Staff Diversity | Urgency: Low
# Parsed 3/3 successfully
# Processed 126/186
#
# Processing batch 126-129
# Parsing line: [0] | Sentiment: Negative | Aspect: Service | Urgency: High
# Parsing line: [1] | Sentiment: Mixed | Aspect: Quality | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Convenience | Urgency: Low
# Parsed 3/3 successfully
# Processed 129/186
#
# Processing batch 129-132
# Parsing line: [0] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality/Convenience | Urgency: High
# Parsing line: [2] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsed 3/3 successfully
# Processed 132/186
#
# Processing batch 132-135
# Parsing line: [0] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Ambiance, Employees | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Ambiance, Employees | Urgency: Low
# Retry 1: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Ambiance, Employees | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Ambiance, Employees | Urgency: Low
# Retry 2: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Ambiance, Employees | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Ambiance, Employees | Urgency: Low
# Retry 3: Parsed 2/3
# Failed to parse after 3 attempts
# Skipping batch 132-135 due to repeated parsing errors.
# Processed 135/186
#
# Processing batch 135-138
# Parsing line: [<0>] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [<1>] | Sentiment: Negative | Aspect: Service | Urgency: High
# Parsing line: [<2>] | Sentiment: Negative | Aspect: Service | Urgency: High
# Parsed 3/3 successfully
# Processed 138/186
#
# Processing batch 138-141
# Parsing line: [<0>] | Sentiment: Negative | Aspect: Service | Urgency: Low
# Parsing line: [<1>] | Sentiment: Mixed | Aspect: Product | Urgency: Medium
# Parsing line: [<2>] | Sentiment: Negative | Aspect: Unknown | Urgency: Low
# Parsed 3/3 successfully
# Processed 141/186
#
# Processing batch 141-144
# Parsing line: [0] | Sentiment: Positive | Aspect: Product | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Convenience/Quality | Urgency: High
# Parsed 3/3 successfully
# Processed 144/186
#
# Processing batch 144-147
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Mixed | Aspect: Product (iced coffee with milk) | Urgency: Low
# Unrecognized format: [1] | Sentiment: Mixed | Aspect: Product (iced coffee with milk) | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Retry 1: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Mixed | Aspect: Product (iced coffee with milk) | Urgency: Low
# Unrecognized format: [1] | Sentiment: Mixed | Aspect: Product (iced coffee with milk) | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Retry 2: Parsed 2/3
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Mixed | Aspect: Product (iced coffee with milk) | Urgency: Low
# Unrecognized format: [1] | Sentiment: Mixed | Aspect: Product (iced coffee with milk) | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Retry 3: Parsed 2/3
# Failed to parse after 3 attempts
# Skipping batch 144-147 due to repeated parsing errors.
# Processed 147/186
#
# Processing batch 147-150
# Parsing line: [<0>] | Sentiment: Positive | Aspect: Product | Urgency: Low
# Parsing line: [<1>] | Sentiment: Negative | Aspect: Service | Urgency: Medium
# Parsing line: [<2>] | Sentiment: Negative | Aspect: Account Management | Urgency: High
# Parsed 3/3 successfully
# Processed 150/186
#
# Processing batch 150-153
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Product | Urgency: High
# Parsing line: [2] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsed 3/3 successfully
# Processed 153/186
#
# Processing batch 153-156
# Parsing line: [<0>] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [<1>] | Sentiment: Positive | Aspect: Experience | Urgency: Low
# Parsing line: [<2>] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsed 3/3 successfully
# Processed 156/186
#
# Processing batch 156-159
# Parsing line: [<0>] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [<1>] | Sentiment: Negative | Aspect: Product (sugar-free option) | Urgency: Medium
# Unrecognized format: [<1>] | Sentiment: Negative | Aspect: Product (sugar-free option) | Urgency: Medium
# Parsing line: [<2>] | Sentiment: Negative | Aspect: Service (customer treatment) | Urgency: High
# Unrecognized format: [<2>] | Sentiment: Negative | Aspect: Service (customer treatment) | Urgency: High
# Retry 1: Parsed 1/3
# Parsing line: [<0>] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [<1>] | Sentiment: Negative | Aspect: Product (sugar-free option) | Urgency: Medium
# Unrecognized format: [<1>] | Sentiment: Negative | Aspect: Product (sugar-free option) | Urgency: Medium
# Parsing line: [<2>] | Sentiment: Negative | Aspect: Service (customer treatment) | Urgency: High
# Unrecognized format: [<2>] | Sentiment: Negative | Aspect: Service (customer treatment) | Urgency: High
# Retry 2: Parsed 1/3
# Parsing line: [<0>] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [<1>] | Sentiment: Negative | Aspect: Product (sugar-free option) | Urgency: Medium
# Unrecognized format: [<1>] | Sentiment: Negative | Aspect: Product (sugar-free option) | Urgency: Medium
# Parsing line: [<2>] | Sentiment: Negative | Aspect: Service (customer treatment) | Urgency: High
# Unrecognized format: [<2>] | Sentiment: Negative | Aspect: Service (customer treatment) | Urgency: High
# Retry 3: Parsed 1/3
# Failed to parse after 3 attempts
# Skipping batch 156-159 due to repeated parsing errors.
# Processed 159/186
#
# Processing batch 159-162
# Parsing line: [0] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality | Urgency: High
# Parsing line: [2] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsed 3/3 successfully
# Processed 162/186
#
# Processing batch 162-165
# Parsing line: [0] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Product | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsed 3/3 successfully
# Processed 165/186
#
# Processing batch 165-168
# Parsing line: [<0>] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [<1>] | Sentiment: Negative | Aspect: Price | Urgency: Medium
# Parsing line: [<2>] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsed 3/3 successfully
# Processed 168/186
#
# Processing batch 168-171
# Parsing line: [0] | Sentiment: Negative | Aspect: Service | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Parsing line: [2] | Sentiment: Positive | Aspect: Quality | Urgency: Low
# Parsed 3/3 successfully
# Processed 171/186
#
# Processing batch 171-174
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Positive | Aspect: Service | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Convenience | Urgency: High
# Parsed 3/3 successfully
# Processed 174/186
#
# Processing batch 174-177
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Mixed | Aspect: Corporate Strategy | Urgency: Low
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsed 3/3 successfully
# Processed 177/186
#
# Processing batch 177-180
# Parsing line: [0] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [1] | Sentiment: Negative | Aspect: Cleanliness | Urgency: Medium
# Parsing line: [2] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsed 3/3 successfully
# Processed 180/186
#
# Processing batch 180-183
# Parsing line: [0] | Sentiment: Mixed | Aspect: Quality | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Price, Service, Cleanliness | Urgency: Medium
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Price, Service, Cleanliness | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Service (Greeting/Welcome) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Service (Greeting/Welcome) | Urgency: Low
# Retry 1: Parsed 1/3
# Parsing line: [0] | Sentiment: Mixed | Aspect: Quality | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Price, Service, Cleanliness | Urgency: Medium
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Price, Service, Cleanliness | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Service (Greeting/Welcome) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Service (Greeting/Welcome) | Urgency: Low
# Retry 2: Parsed 1/3
# Parsing line: [0] | Sentiment: Mixed | Aspect: Quality | Urgency: Low
# Parsing line: [1] | Sentiment: Negative | Aspect: Price, Service, Cleanliness | Urgency: Medium
# Unrecognized format: [1] | Sentiment: Negative | Aspect: Price, Service, Cleanliness | Urgency: Medium
# Parsing line: [2] | Sentiment: Positive | Aspect: Service (Greeting/Welcome) | Urgency: Low
# Unrecognized format: [2] | Sentiment: Positive | Aspect: Service (Greeting/Welcome) | Urgency: Low
# Retry 3: Parsed 1/3
# Failed to parse after 3 attempts
# Skipping batch 180-183 due to repeated parsing errors.
# Processed 183/186
#
# Processing batch 183-186
# Parsing line: [0] | Sentiment: Negative | Aspect: Service | Urgency: High
# Parsing line: [1] | Sentiment: Negative | Aspect: Quality | Urgency: Medium
# Parsing line: [2] | Sentiment: Unknown | Aspect: Unknown | Urgency: Unknown
# Parsed 3/3 successfully
# Processed 186/186

# %%
# Merge parsed results into DataFrame
df_results = pd.DataFrame(results)
df_results.set_index('original_index', inplace=True)

df_final = df.copy()
df_final = df_final.join(df_results, how='left')

# Show sample rows
print("Sample of Final Classified Reviews:")
display(df_final[['clean_review', 'sentiment', 'aspect', 'urgency']].head())

# Summary Statistics
print("\nClassification Distribution:")
print("-" * 40)
print("Sentiment counts:\n", df_final['sentiment'].value_counts(dropna=False))
print("\nAspect counts:\n", df_final['aspect'].value_counts(dropna=False))
print("\nUrgency counts:\n", df_final['urgency'].value_counts(dropna=False))

# Missing classification check
missing = df_final[['sentiment', 'aspect', 'urgency']].isna().sum()
if missing.any():
    print("\nMissing values detected:")
    print(missing)
    incomplete = df_final[df_final[['sentiment', 'aspect', 'urgency']].isna().any(axis=1)]
else:
    print("\nAll rows fully classified — no NaNs")

# Save full output
df_final.to_csv("review_analysis_result.csv", index=False)
print("Final result saved to 'review_analysis_result.csv'")
# Out:
# Sample of Final Classified Reviews:
#                                         clean_review sentiment   aspect  \
# 0                                     no_review text     Mixed    Price
# 1  i have only purchased their coffee their price...  Negative    Price
# 2  i was visiting the  at 2183 vista way in ocean...  Negative  Service
# 3  in cathedral city ca needs more baristas servi...  Negative  Service
# 4  ordered my usual tall iced doppio espresso wit...  Negative    Price
#
#   urgency
# 0     Low
# 1     Low
# 2  Medium
# 3  Medium
# 4     Low
# Classification Distribution:
# ----------------------------------------
# Sentiment counts:
#  sentiment
# Negative    90
# NaN         60
# Positive    20
# Mixed       13
# Unknown      2
# Neutral      1
# Name: count, dtype: int64
#
# Aspect counts:
#  aspect
# Unknown         63
# NaN             60
# Service         36
# Price           13
# Product          9
# Availability     2
# Ambiance         1
# Wait Time        1
# Cleanliness      1
# Name: count, dtype: int64
#
# Urgency counts:
#  urgency
# NaN        60
# Medium     50
# Low        39
# High       36
# Unknown     1
# Name: count, dtype: int64
#
# Missing values detected:
# sentiment    60
# aspect       60
# urgency      60
# dtype: int64
# Final result saved to 'review_analysis_result.csv'

# %% [markdown]
# ## **Insights from LLM Analysis**
#
# - What aspects trigger most complaints per state?
# - Which aspects are most urgent?
# - Common keywords in negative/mixed reviews
# - and Actionable Recommendations
#
# Each summary is processed and with the end goal of clearly tell us as the "manager" of what to do for each state the best course of action

# %%
from collections import Counter
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def extract_top_keywords(texts, top_n=5):
    all_words = ' '.join(texts).lower().split()
    filtered = [word for word in all_words if word not in stop_words and len(word) > 2]
    common = Counter(filtered).most_common(top_n)
    return [word for word, _ in common]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def generate_insights(df_combined):
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns
    plt.switch_backend('Agg')
    print("\n--- Generating Insights and Visualizations ---")

    # Prepare complaint data
    complaints = df_combined[
        df_combined['sentiment'].isin(['Negative', 'Mixed'])
    ].copy()

    complaints['aspect'] = complaints['aspect'].fillna('Unknown').replace('', 'Unknown')
    complaints['urgency'] = complaints['urgency'].fillna('Medium').replace('', 'Medium')

    if complaints.empty:
        print("⚠ No complaints to analyze.")
        return pd.DataFrame()

    # Scoring
    complaints['urgency_score'] = complaints['urgency'].map({'High': 3, 'Medium': 2, 'Low': 1}).fillna(0)
    complaints['frequency_score'] = complaints.groupby(['state', 'aspect'])['aspect'].transform('count')

    total_complaints = len(complaints)
    complaints['frequency_score'] = complaints['frequency_score'] / total_complaints if total_complaints > 0 else 0
    complaints['rating_impact_score'] = (5 - complaints['Rating']) / 4

    complaints['priority_score'] = (
        0.5 * complaints['urgency_score'] +
        0.3 * complaints['frequency_score'] +
        0.2 * complaints['rating_impact_score']
    ).round(2)

    # KPI and impact mappings
    kpi_mapping = {
        'Service': {'target': 'CSAT ≥ 90%', 'action': 'Barista training'},
        'Product': {'target': 'Score ≥ 4.2', 'action': 'Weekly QC'},
        'Ambiance': {'target': 'Rating ≥ 4.5', 'action': 'Clean audits'},
        'Wait Time': {'target': 'Avg < 3.5min', 'action': 'Optimize schedule'},
        'Price': {'target': 'Score ≥ 4.0', 'action': 'Loyalty value packs'},
        'Cleanliness': {'target': '≥ 4.8', 'action': 'Enhanced cleaning'},
        'Availability': {'target': '≥ 98%', 'action': 'Stock coordination'},
        'Unknown': {'target': 'Reduce Unknown 50%', 'action': 'LLM Deep Dive'}
    }

    impact_map = {
        'Service': 'High', 'Product': 'High', 'Wait Time': 'High',
        'Price': 'Medium', 'Ambiance': 'Medium', 'Cleanliness': 'High',
        'Availability': 'Medium', 'Unknown': 'Low'
    }

    # Group by state and aspect to get priority
    priority_issues = (
        complaints.groupby(['state', 'aspect'])
        .agg(priority_score=('priority_score', 'mean'), count=('aspect', 'size'))
        .reset_index()
        .sort_values(['state', 'priority_score'], ascending=[True, False])
    )

    priority_issues['kpi_target'] = priority_issues['aspect'].map(lambda x: kpi_mapping.get(x, {}).get('target', 'N/A'))
    priority_issues['kpi_action'] = priority_issues['aspect'].map(lambda x: kpi_mapping.get(x, {}).get('action', 'Analyze further'))
    priority_issues['expected_impact'] = priority_issues['aspect'].map(lambda x: impact_map.get(x, 'Medium'))

    # Extract keywords
    keyword_summary = (
        complaints.groupby(['state', 'aspect'])['clean_review']
        .apply(lambda x: extract_top_keywords(x.tolist(), top_n=5))
        .reset_index(name='common_keywords')
    )

    sentiment_counts = (
        df_combined
        .groupby(['state', 'aspect', 'sentiment'])
        .size()
        .unstack(fill_value=0)
        .reset_index()
        .rename(columns={
            'Positive': 'positive_count',
            'Negative': 'negative_count',
            'Mixed': 'mixed_count'
        })
    )

    # Merge all together
    final_report = (
        priority_issues
        .merge(keyword_summary, on=['state', 'aspect'], how='left')
        .merge(sentiment_counts, on=['state', 'aspect'], how='left')
    )

    print("\nTop Priority Issues per State:")
    print(final_report.head(10))

    return final_report

# %%
priority_issues = generate_insights(df_final)
priority_issues.to_csv("priority_issues_summary.csv", index=False, encoding="utf-8-sig")
# Out:
# --- Generating Insights and Visualizations ---
#
# Top Priority Issues per State:
#   state        aspect  priority_score  count          kpi_target  \
# 0    CA       Service        1.360833     13          CSAT ≥ 90%
# 1    CA       Unknown        1.306087     28  Reduce Unknown 50%
# 2    CA      Ambiance        1.200000      1        Rating ≥ 4.5
# 3    CA       Product        1.160000      3         Score ≥ 4.2
# 4    CA         Price        1.123750      9         Score ≥ 4.0
# 5    CA  Availability        0.710000      2               ≥ 98%
# 6    FL       Product        1.710000      2         Score ≥ 4.2
# 7    FL     Wait Time        1.650000      1        Avg < 3.5min
# 8    FL       Service        1.360000      7          CSAT ≥ 90%
# 9    FL       Unknown        1.289091     12  Reduce Unknown 50%
#
#             kpi_action expected_impact  \
# 0     Barista training            High
# 1        LLM Deep Dive             Low
# 2         Clean audits          Medium
# 3            Weekly QC            High
# 4  Loyalty value packs          Medium
# 5   Stock coordination          Medium
# 6            Weekly QC            High
# 7    Optimize schedule            High
# 8     Barista training            High
# 9        LLM Deep Dive             Low
#
#                                    common_keywords  mixed_count  \
# 0       [coffee, order, service, always, customer]            0
# 1                  [card, coffee, said, one, time]            7
# 2     [lyrics, find, overhead, music, offensively]            0
# 3  [coffee, grinding, ordered, frappuccino, beans]            1
# 4              [get, charged, coffee, asked, said]            2
# 5            [coffee, loud, email, order, vallejo]            0
# 6            [drink, also, ordered, lacked, sugar]            1
# 7            [tea, milk, thanks, store, roosevelt]            0
# 8                 [drink, never, lady, drive, got]            0
# 9                  [card, account, went, got, one]            1
#
#    negative_count  Neutral  positive_count  Unknown
# 0              13        1               3        0
# 1              21        0               3        1
# 2               1        0               0        0
# 3               2        0               0        0
# 4               7        0               0        0
# 5               2        0               0        0
# 6               1        0               1        0
# 7               1        0               0        0
# 8               7        0               3        0
# 9              11        0               1        0
